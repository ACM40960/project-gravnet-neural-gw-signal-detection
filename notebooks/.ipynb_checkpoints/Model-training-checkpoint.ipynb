# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

#loading the data
x = np.load("results/x.npy")
y = np.load("results/y.npy")

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, stratify = y, random_state = 42)
print("x_train shape: ", x_train.shape)
print("x_test shape: ", x_test.shape)

#Building up a 2D CNN model
model = models.Sequential([
    layers.Input(shape=(257, 31, 1)),

    layers.Conv2D(32, (7, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 1)),

    layers.Conv2D(64, (5, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 1)),

    layers.Conv2D(128, (3, 2), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),

    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid')
])



model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics = ['accuracy'])

model.summary()

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5, 
                              restore_best_weights = True)

history = model.fit(
    x_train, y_train,
    epochs = 30,
    batch_size = 32,
    validation_data = (x_test, y_test),
    callbacks = early_stopping
)
# Out:
# x_train shape:  (750, 257, 31, 1)
# x_test shape:  (250, 257, 31, 1)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 257, 31, 32)       704
#
#  batch_normalization_21 (Ba  (None, 257, 31, 32)       128
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 128, 31, 32)       0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 128, 31, 64)       30784
#
#  batch_normalization_22 (Ba  (None, 128, 31, 64)       256
#  tchNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 64, 31, 64)        0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 31, 128)       49280
#
#  batch_normalization_23 (Ba  (None, 64, 31, 128)       512
#  tchNormalization)
#
#  global_average_pooling2d_7  (None, 128)               0
#   (GlobalAveragePooling2D)
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 89985 (351.50 KB)
# Trainable params: 89537 (349.75 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1/30
# 24/24 [==============================] - 6s 144ms/step - loss: 0.6444 - accuracy: 0.7093 - val_loss: 0.7190 - val_accuracy: 0.5000
# Epoch 2/30
# 24/24 [==============================] - 3s 123ms/step - loss: 0.3273 - accuracy: 0.9320 - val_loss: 0.9591 - val_accuracy: 0.5000
# Epoch 3/30
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0604 - accuracy: 0.9987 - val_loss: 0.8495 - val_accuracy: 0.5000
# Epoch 4/30
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.7862 - val_accuracy: 0.5000
# Epoch 5/30
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0247 - accuracy: 0.9960 - val_loss: 1.3530 - val_accuracy: 0.5000
# Epoch 6/30
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 2.2862 - val_accuracy: 0.5000

# %%
y_prob = model.predict(x_test)
# Out:
# 8/8 [==============================] - 1s 82ms/step

# %%
print("Prediction range:", np.min(y_prob), "to", np.max(y_prob))
# Out:
# Prediction range: 0.3752936 to 0.39474684

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# Load preprocessed spectrogram data
x = np.load("results/x.npy")
y = np.load("results/y.npy")

# Split into training and test sets
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, stratify=y, random_state=42)

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)

# Define CNN model
model = models.Sequential([
    layers.Input(shape=(129, 30, 1)),

    layers.Conv2D(32, (7, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 1)),

    layers.Conv2D(64, (5, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 1)),

    layers.Conv2D(128, (3, 2), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),

    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

# Setup early stopping
early_stopping = EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=32,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping]
)

# Evaluate predictions
y_prob = model.predict(x_test)
print("Prediction range:", np.min(y_prob), "to", np.max(y_prob))
# Out:
# x_train shape: (750, 129, 30, 1)
# x_test shape: (250, 129, 30, 1)
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_66 (Conv2D)          (None, 129, 30, 32)       704
#
#  batch_normalization_72 (Ba  (None, 129, 30, 32)       128
#  tchNormalization)
#
#  max_pooling2d_44 (MaxPooli  (None, 64, 30, 32)        0
#  ng2D)
#
#  conv2d_67 (Conv2D)          (None, 64, 30, 64)        30784
#
#  batch_normalization_73 (Ba  (None, 64, 30, 64)        256
#  tchNormalization)
#
#  max_pooling2d_45 (MaxPooli  (None, 32, 30, 64)        0
#  ng2D)
#
#  conv2d_68 (Conv2D)          (None, 32, 30, 128)       49280
#
#  batch_normalization_74 (Ba  (None, 32, 30, 128)       512
#  tchNormalization)
#
#  global_average_pooling2d_2  (None, 128)               0
#  2 (GlobalAveragePooling2D)
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_41 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 89985 (351.50 KB)
# Trainable params: 89537 (349.75 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1/30
# 24/24 [==============================] - 4s 76ms/step - loss: 0.6906 - accuracy: 0.5360 - val_loss: 1.4462 - val_accuracy: 0.5000
# Epoch 2/30
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6619 - accuracy: 0.6600 - val_loss: 1.6324 - val_accuracy: 0.5000
# Epoch 3/30
# 24/24 [==============================] - 1s 61ms/step - loss: 0.5610 - accuracy: 0.7667 - val_loss: 1.3385 - val_accuracy: 0.5000
# Epoch 4/30
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3813 - accuracy: 0.8627 - val_loss: 2.1817 - val_accuracy: 0.5000
# Epoch 5/30
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1977 - accuracy: 0.9427 - val_loss: 2.7492 - val_accuracy: 0.5000
# Epoch 6/30
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0894 - accuracy: 0.9760 - val_loss: 1.8193 - val_accuracy: 0.5000
# Epoch 7/30
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0851 - accuracy: 0.9747 - val_loss: 0.8252 - val_accuracy: 0.5760
# Epoch 8/30
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0694 - accuracy: 0.9813 - val_loss: 0.5183 - val_accuracy: 0.7320
# Epoch 9/30
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0424 - accuracy: 0.9880 - val_loss: 3.1800 - val_accuracy: 0.5000
# Epoch 10/30
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0194 - accuracy: 0.9973 - val_loss: 4.2582 - val_accuracy: 0.5040
# Epoch 11/30
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 5.1112 - val_accuracy: 0.5040
# Epoch 12/30
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 1.4007 - val_accuracy: 0.6720
# Epoch 13/30
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0297 - accuracy: 0.9867 - val_loss: 16.4125 - val_accuracy: 0.5000
# 8/8 [==============================] - 0s 14ms/step
# Prediction range: 0.011709846 to 0.992121
